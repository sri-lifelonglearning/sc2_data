# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from m3t.data import load_trajectory
import matplotlib.animation as animation
import matplotlib
from IPython.display import HTML
# %matplotlib inline

# %%
import os
os.path.isfile()
# Out:
# 'C:\\l2m\\l2m_data'

# %%
data = load_trajectory("trajectories/ste_fullyconv2/CollectMineralShards/ep0.pkl.gz")
print(data.observations[2].shape)
print(data.observations[0].shape)
# Out:
# (240, 256, 256, 3)
# (240, 27, 64, 64)

# %%
# view a feature layer
plt.imshow(data.observations[0][0][14])

# %%
# view rgb data
plt.imshow(data.observations[2][0])

# %%
def show_gif(observations):
    fps = 30
    nSeconds = 5
    fig = plt.figure( figsize=(8,8) )
    a = observations[0][1]
    im = plt.imshow(a, interpolation='nearest', aspect='auto', vmin=0, vmax=1)

    def animate_func(i):
        if i % fps == 0:
            print( '.', end ='' )

        im.set_array(observations[i])
        return [im]

    anim = matplotlib.animation.FuncAnimation(fig, animate_func, frames=len(observations))
    return anim

# %%
anim = show_gif(data.observations[2])
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 anim = show_gif(data.observations[2])
# ----> 2 HTML(anim.to_html5_video())
#
# File C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\animation.py:1264, in Animation.to_html5_video(self, embed_limit)
#    1261 path = Path(tmpdir, "temp.m4v")
#    1262 # We create a writer manually so that we can get the
#    1263 # appropriate size for the tag
# -> 1264 Writer = writers[mpl.rcParams['animation.writer']]
#    1265 writer = Writer(codec='h264',
#    1266                 bitrate=mpl.rcParams['animation.bitrate'],
#    1267                 fps=1000. / self._interval)
#    1268 self.save(str(path), writer=writer)
#
# File C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\animation.py:151, in MovieWriterRegistry.__getitem__(self, name)
#     149 if self.is_available(name):
#     150     return self._registered[name]
# --> 151 raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
